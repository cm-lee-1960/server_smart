# %%
# !pip install pyautogui
# Out:
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#     Preparing wheel metadata: started
#     Preparing wheel metadata: finished with status 'done'
# ...
#   Created wheel for pyautogui: filename=PyAutoGUI-0.9.53-py3-none-any.whl size=36613 sha256=6a339d609bea550f15417698fa8a57e9344371f7dcbefcc8abbdcb7b870ca005
#   Stored in directory: c:\users\이지혜\appdata\local\pip\cache\wheels\d8\97\e4\d2edca92a87d3b5fbfb527264750a17b4ba297b9a7cab6e67f
# ...

# %%
import pyautogui

# %%
pyautogui.position()
# Out:
# Point(x=389, y=416)

# %%
pyautogui.screenshot('삼양동_2020_5G.png', region=(389,416,1125,290))
# Out:
# <PIL.Image.Image image mode=RGB size=1125x290 at 0x1FDE62ED1F0>
